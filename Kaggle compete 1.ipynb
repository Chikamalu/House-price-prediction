# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/Chika/Downloads/housing.csv/Kaggle ML/train.csv")
df1 = pd.read_csv("C:/Users/Chika/Downloads/housing.csv/Kaggle ML/test.csv")

df.shape
# Out:
# (1460, 81)

# %%
pd.set_option("display.max.columns", None)

# %%
#fill in the blanks/na cells
a = df.columns
array_val =[]
for i in a:
    modal_val = df[i].mode()
    array_val.append(modal_val)
new_array = np.array(array_val)
array_new_val = [l[0] for l in new_array]
modal_array_values = np.array(array_new_val)
dict_missing = dict(zip(a, modal_array_values))
for l, k in dict_missing.items():
    df[l] = df[l].fillna(k)

df
# Out:
# <ipython-input-122-85bae9bac658>:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   new_array = np.array(array_val)
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL        65.0     8450   Pave  Grvl      Reg
# 1        2          20       RL        80.0     9600   Pave  Grvl      Reg
# 2        3          60       RL        68.0    11250   Pave  Grvl      IR1
# 3        4          70       RL        60.0     9550   Pave  Grvl      IR1
# 4        5          60       RL        84.0    14260   Pave  Grvl      IR1
# ...    ...         ...      ...         ...      ...    ...   ...      ...
# 1455  1456          60       RL        62.0     7917   Pave  Grvl      Reg
# ...

# %%
#change some of the values that are supposed to be numeric to numeric 
df['LotFrontage']=pd.to_numeric(df['LotFrontage'])
df['GarageYrBlt']=pd.to_numeric(df['GarageYrBlt'])
df['MasVnrArea']=pd.to_numeric(df['MasVnrArea'])
# h_data['BsmtFinSF1']=pd.to_numeric(h_data['BsmtFinSF1'])
# h_data['BsmtFinSF2']=pd.to_numeric(h_data['BsmtFinSF2'])
# h_data['BsmtUnfSF']=pd.to_numeric(h_data['BsmtUnfSF'])
# h_data['TotalBsmtSF']=pd.to_numeric(h_data['TotalBsmtSF'])
# h_data['BsmtFullBath']=pd.to_numeric(h_data['BsmtFullBath'])
# h_data['BsmtHalfBath']=pd.to_numeric(h_data['BsmtHalfBath'])
# h_data['GarageCars']=pd.to_numeric(h_data['GarageCars'])
# h_data['GarageArea']=pd.to_numeric(h_data['GarageArea'])

# %%
#correlation matrix
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
#take out the column to be predicted
n=df.columns
x_col=n[:80]
x_data=df[x_col]
m = df['SalePrice']
m
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
#separate the columns that are numeric
h=x_data.select_dtypes(include=np.number)
num=h.columns.to_list()
numeric=x_data[num]
numeric
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
#separate the non numeric columns
j=x_data.select_dtypes(include=np.object)
nonum=j.columns.to_list()
non_numeric=x_data[nonum]
non_numeric.head(2)
# Out:
# <ipython-input-128-59bed0a712b6>:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   j=x_data.select_dtypes(include=np.object)
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave  Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave  Grvl      Reg         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
#
#   Exterior1st Exterior2nd MasVnrType ExterQual ExterCond Foundation BsmtQual  \
# ...

# %%
from sklearn import preprocessing
# X = df.iloc[:,:-1].values
# Y = df.iloc[:, 80].values

# %%
#encode the categorical columns 
from sklearn import preprocessing 
label_encoder=preprocessing.LabelEncoder()

pn=non_numeric.columns
for i in pn:
     non_numeric[i]=label_encoder.fit_transform(non_numeric[i])
non_numeric.head()
# Out:
# <ipython-input-130-e8382b9992df>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_numeric[i]=label_encoder.fit_transform(non_numeric[i])
#    MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0         3       1      0         3            3          0          4
# 1         3       1      0         3            3          0          2
# 2         3       1      0         0            3          0          4
# 3         3       1      0         0            3          0          0
# 4         3       1      0         0            3          0          2
#
#    LandSlope  Neighborhood  Condition1  Condition2  BldgType  HouseStyle  \
# 0          0             5           2           2         0           5
# ...

# %%
#concat the numeric and categorical columns
concat_data=pd.concat([numeric,non_numeric],axis=1)
concat_data
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

#split the data into train and test
# X_train, X_test, y_train, y_test=train_test_split(concat_data, m ,test_size=0.29, random_state = 4)
# X_train

# %%
#fitting multiple linear regression to the training set
lr=LinearRegression()
# linear= lr.fit(X_train,y_train)
# met=lr.score(X_train,y_train)
# met

# %%
#predicting the test set result
# Out:
# 847

# %%
#Calculating the coefficients
print(lr.coef_)
# Out:
# [-2.09506575e+01 -4.72204519e+01 -6.33275685e+01  5.81169597e-01
#   3.10697144e+03  4.71020066e+03  2.66324115e+02 -7.20825025e+01
#   1.01699134e+01  7.65457668e+00  3.15789824e+00  2.00906622e+00
#   1.28215409e+01  7.75587926e+00  1.88411868e+01 -1.47343276e+01
#   1.18627384e+01  9.58976257e+02 -5.17025521e+02  2.05837874e+03
#  -3.77273236e+03 -6.93380644e+03 -1.81014167e+04  6.10717127e+03
#   2.42579164e+03 -4.30573690e+01  1.38664999e+02  6.27933160e+00
#   2.97961629e+00 -1.70428070e+01 -4.82750963e+00  1.56596530e+01
#   4.97259073e+01  1.69526524e+02 -2.01728537e+00  7.13401408e+02
#  -2.95472999e+03 -1.69259061e+01 -1.94824700e+03 -2.40602331e+03
#   5.43678999e+02  1.77462119e+03 -2.96718515e+04 -5.63298962e+01
#  -1.39790334e+03  3.44115662e+02 -1.08797306e+03 -5.65982342e+03
#  -9.57491436e+02 -3.62260789e+02  9.63008203e+02  2.45687807e+03
#  -4.74996846e+02  1.43767062e+02  6.22610172e+03 -7.30419293e+03
# ...

# %%
# Out:
# 5751526.688290222

# %%
# calculating the R squared value
from sklearn.metrics import r2_score
r2_score(y_test, ypred)
# Out:
# 0.3514014413050832

# %%
a = df1.columns
array_val =[]
for i in a:
    modal_val = df1[i].mode()
    array_val.append(modal_val)
new_array = np.array(array_val)
array_new_val = [l[0] for l in new_array]
modal_array_values = np.array(array_new_val)
dict_missing = dict(zip(a, modal_array_values))
for l, k in dict_missing.items():
    df1[l] = df1[l].fillna(k)

df1

df1['LotFrontage']=pd.to_numeric(df1['LotFrontage'])
df1['GarageYrBlt']=pd.to_numeric(df1['GarageYrBlt'])
df1['MasVnrArea']=pd.to_numeric(df1['MasVnrArea'])
df1['BsmtFinSF1']=pd.to_numeric(df1['BsmtFinSF1'])
df1['BsmtFinSF2']=pd.to_numeric(df1['BsmtFinSF2'])
df1['BsmtUnfSF']=pd.to_numeric(df1['BsmtUnfSF'])
df1['TotalBsmtSF']=pd.to_numeric(df1['TotalBsmtSF'])
df1['BsmtFullBath']=pd.to_numeric(df1['BsmtFullBath'])
df1['BsmtHalfBath']=pd.to_numeric(df1['BsmtHalfBath'])
df1['GarageCars']=pd.to_numeric(df1['GarageCars'])
df1['GarageArea']=pd.to_numeric(df1['GarageArea'])

#take out the column to be predicted
# nim=df1.columns
# xcoil=nim[:80]
# xidata=df1[xcoil]
#m = h_data['SalePrice']

#separate the columns that are numeric
hin=df1.select_dtypes(include=np.number)
numi=hin.columns.to_list() # converts to an array
numerici=df1[numi]

#separate the non numeric columns
jim=df1.select_dtypes(include=np.object)
no_num=jim.columns.to_list()
catego =df1[nonum]

#encode the categorical columns 
label_encoder=preprocessing.LabelEncoder()

pin =catego.columns
for i in pin:
     catego[i]=label_encoder.fit_transform(catego[i])
catego

data2 =pd.concat([numerici,catego],axis=1)
data2.head(2)
# Out:
# <ipython-input-133-a3a13111e217>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   new_array = np.array(array_val)
# <ipython-input-133-a3a13111e217>:39: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   jim=df1.select_dtypes(include=np.object)
# <ipython-input-133-a3a13111e217>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
X_train = concat_data
X_test = data2
y_train = df['SalePrice']
model = LinearRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
len(predictions)
submission = df1[['Id']]
submission['SalePrice'] = predictions
submission
# Out:
# <ipython-input-140-3df512085807>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission['SalePrice'] = predictions
#         Id      SalePrice
# 0     1461  342341.599252
# 1     1462  393283.886147
# 2     1463  401650.933489
# 3     1464  420255.824603
# 4     1465  421764.571737
# ...    ...            ...
# 1454  2915  305939.864825
# 1455  2916  291992.809377
# 1456  2917  374978.266031
# 1457  2918  350039.845586
# 1458  2919  473497.732020
#
# [1459 rows x 2 columns]

# %%
submission.to_csv('submission.csv', index = None)

# %%
#Calculating the intercept
print(lr.intercept_)
ypred = lr.predict(X_test)
ypred
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-9eb2cd8a23c6> in <module>
#       1 #Calculating the intercept
# ----> 2 print(lr.intercept_)
#       3 ypred = lr.predict(X_test)
#       4 ypred
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'
